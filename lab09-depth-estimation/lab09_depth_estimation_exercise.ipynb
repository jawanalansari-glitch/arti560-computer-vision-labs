# %%
# !git clone https://github.com/LiheYoung/Depth-Anything.git
# Out:
# fatal: destination path 'Depth-Anything' already exists and is not an empty directory.

# %%
# %cd Depth-Anything
# Out:
# /content/Depth-Anything

# %%
# !pip install -r requirements.txt
# Out:
# ...
# WARNING: typer 0.24.2 does not provide the extra 'all'
# ...

# %%
# !python run.py --img-path assets/examples/demo5.png --outdir output --grayscale
# Out:
# ...
# config.json: 100% 116/116 [00:00<00:00, 615kB/s]
# xFormers not available
# xFormers not available
# pytorch_model.bin: 100% 1.34G/1.34G [00:16<00:00, 83.7MB/s]
# Total parameters: 335.32M
# 100% 1/1 [00:02<00:00,  2.17s/it]

# %%
# !python run.py --img-path assets/examples/demo10.png --outdir output
# Out:
# ...
# xFormers not available
# xFormers not available
# Total parameters: 335.32M
# 100% 1/1 [00:01<00:00,  1.44s/it]

# %%
# !python run_video.py --video-path assets/examples_video/davis_rollercoaster.mp4 --outdir output_video
# Out:
# xFormers not available
# xFormers not available
# ...
# Total parameters: 335.32M
# Progress 1/1, Processing assets/examples_video/davis_rollercoaster.mp4
